# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('D:\Projects\Python_Data_Project\data_jobs.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# <>:1: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\Akkju\AppData\Local\Temp\ipykernel_10748\858677744.py:1: SyntaxWarning: invalid escape sequence '\P'
#   df = pd.read_csv('D:\Projects\Python_Data_Project\data_jobs.csv')

# %%
df['job_posted_date'] = pd.to_datetime(df["job_posted_date"])

# %%
df.sample() #Getting a random sample
# Out:
#        job_title_short            job_title     job_location  \
# 727331   Data Engineer  Azure Data Engineer  Winter Park, FL
#
#                  job_via job_schedule_type  job_work_from_home  \
# 727331  via ZipRecruiter         Full-time               False
#
#                search_location     job_posted_date  job_no_degree_mention  \
# 727331  Florida, United States 2023-11-28 21:09:31                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 727331                  True  United States         NaN              NaN
#
#         salary_hour_avg   company_name  \
# 727331              NaN  EmpiRx Health
#
#                                                job_skills  \
# 727331  ['sql', 'python', 'c#', 'powershell', 'sql ser...
#
#                                           job_type_skills
# 727331  {'analyst_tools': ['excel', 'power bi', 'ssrs'...

# %%
df.sample(10)
# Out:
#               job_title_short  \
# 420736          Data Engineer
# 490205  Senior Data Scientist
# 602320       Business Analyst
# 748030    Senior Data Analyst
# 340130          Data Engineer
# 211744         Data Scientist
# 431260           Data Analyst
# 382815         Data Scientist
# 513511  Senior Data Scientist
# 196732          Data Engineer
#
#                                                 job_title  \
# 420736  Azure Data Engineer- Office Job – Pune, Bangal...
# 490205                              Senior Data Scientist
# 602320                Business Information Analist - Data
# 748030                                Senior Data Analyst
# 340130                                      Data Engineer
# 211744                                     DATA SCIENTIST
# 431260                          Data Analyst - Alternance
# 382815                                     Data Scientist
# 513511                 Senior DS Computer Vision engineer
# ...

# %%
df.sample(10, random_state= 0 ) # random state give the same sample without changing results
# Out:
#              job_title_short                                 job_title  \
# 714934     Software Engineer                           Product Analyst
# 397245          Data Analyst                              Data Analyst
# 617736        Data Scientist  AVP - Data Science Team (Analytics Team)
# 624251          Data Analyst                                高级大数据开发工程师
# 263814         Data Engineer                            Data Engineers
# 130747          Data Analyst                    Marketing Data Analyst
# 458472   Senior Data Analyst            Senior Data Management Analyst
# 601012         Data Engineer          Machine Learning / Data Engineer
# 637566  Senior Data Engineer    Senior Data Center Engineer（高级数据中心工程师）
# 605112        Data Scientist                            Data Scientist
#
#                                              job_location          job_via  \
# 714934  Kuala Lumpur, Federal Territory of Kuala Lumpu...     via LinkedIn
# ...

# %%
df2 = df.copy() #Creates a copy of the dataframe instead of referencing
